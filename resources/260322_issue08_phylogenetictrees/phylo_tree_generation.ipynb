# %%
import psycopg2
import subprocess
# Out:
# <frozen importlib._bootstrap>:491: RuntimeWarning: The global interpreter lock (GIL) has been enabled to load module 'psycopg2._psycopg', which has not declared that it can run safely without the GIL. To override this behavior and keep the GIL disabled (at your own risk), run with PYTHON_GIL=0 or -Xgil=0.

# %%
# Add family size information to the DataFrame, pull this from the database
DB = {
    "host":     "petadex.ccz9y6yshbls.us-east-1.rds.amazonaws.com",
    "port":     5432,
    "database": "petadex",
    "user":     "readonly_user",
    "password": "petadex",
}

conn = psycopg2.connect(**DB)
cur  = conn.cursor()

# %%
cur.execute("""SELECT DISTINCT family, COUNT(*)
            FROM enzyme_taxonomy
            WHERE family IS NOT NULL
            GROUP BY family
            """)
families = cur.fetchall()

# %%
OUTPUT_DIR = "./data/families"

# %%
import os
# batched calls to PostGreSQL to avoid memory issues and speed up processing
family_ids = [f[0] for f in families]
batch_size = 1000

for i in range(0, len(family_ids), batch_size):
    batch = family_ids[i:i+batch_size]
    
    # 1. Fetch the batch of families and their corresponding enzyme sequences
    cur.execute("""
        SELECT family, enzyme_fastaa.enzyme_id, translated_sequence 
        FROM enzyme_taxonomy
        JOIN enzyme_fastaa ON enzyme_taxonomy.enzyme_id = enzyme_fastaa.enzyme_id
        WHERE family IN %s
    """, (tuple(batch),))
    results = cur.fetchall()

    # 2. Group the results by family
    family_data = {}
    for fam_id, enz_id, seq in results:
        if fam_id not in family_data:
            family_data[fam_id] = []
        family_data[fam_id].append(f">{enz_id}\n{seq}\n")

    # 3. Write each family to its own .fasta file
    for fam_id, fasta_lines in family_data.items():
        fasta_path = os.path.join(OUTPUT_DIR, f"{fam_id}.fasta")
        with open(fasta_path, "w") as f:
            f.writelines(fasta_lines)

    print(f"Processed batch {i//batch_size + 1}: Created {len(family_data)} FASTA files.")
# Out:
# Processed batch 1: Created 1000 FASTA files.
# Processed batch 2: Created 1000 FASTA files.
# Processed batch 3: Created 1000 FASTA files.
# Processed batch 4: Created 1000 FASTA files.
# Processed batch 5: Created 1000 FASTA files.
# Processed batch 6: Created 1000 FASTA files.
# Processed batch 7: Created 1000 FASTA files.
# Processed batch 8: Created 1000 FASTA files.
# Processed batch 9: Created 1000 FASTA files.
# Processed batch 10: Created 1000 FASTA files.
# Processed batch 11: Created 1000 FASTA files.
# Processed batch 12: Created 1000 FASTA files.
# Processed batch 13: Created 1000 FASTA files.
# Processed batch 14: Created 1000 FASTA files.
# Processed batch 15: Created 1000 FASTA files.
# Processed batch 16: Created 1000 FASTA files.
# Processed batch 17: Created 1000 FASTA files.
# Processed batch 18: Created 1000 FASTA files.
# Processed batch 19: Created 1000 FASTA files.
# Processed batch 20: Created 1000 FASTA files.
# Processed batch 21: Created 1000 FASTA files.
# Processed batch 22: Created 1000 FASTA files.
# Processed batch 23: Created 1000 FASTA files.
# Processed batch 24: Created 1000 FASTA files.
# Processed batch 25: Created 1000 FASTA files.
# Processed batch 26: Created 1000 FASTA files.
# Processed batch 27: Created 1000 FASTA files.
# Processed batch 28: Created 1000 FASTA files.
# Processed batch 29: Created 1000 FASTA files.
# Processed batch 30: Created 1000 FASTA files.
# Processed batch 31: Created 1000 FASTA files.
# Processed batch 32: Created 1000 FASTA files.
# Processed batch 33: Created 1000 FASTA files.
# Processed batch 34: Created 1000 FASTA files.
# Processed batch 35: Created 1000 FASTA files.
# Processed batch 36: Created 1000 FASTA files.
# Processed batch 37: Created 1000 FASTA files.
# Processed batch 38: Created 1000 FASTA files.
# Processed batch 39: Created 1000 FASTA files.
# Processed batch 40: Created 1000 FASTA files.
# Processed batch 41: Created 1000 FASTA files.
# Processed batch 42: Created 1000 FASTA files.
# Processed batch 43: Created 1000 FASTA files.
# Processed batch 44: Created 1000 FASTA files.
# Processed batch 45: Created 1000 FASTA files.
# Processed batch 46: Created 1000 FASTA files.
# Processed batch 47: Created 1000 FASTA files.
# Processed batch 48: Created 1000 FASTA files.
# Processed batch 49: Created 1000 FASTA files.
# Processed batch 50: Created 1000 FASTA files.
# Processed batch 51: Created 1000 FASTA files.
# Processed batch 52: Created 1000 FASTA files.
# Processed batch 53: Created 1000 FASTA files.
# Processed batch 54: Created 1000 FASTA files.
# Processed batch 55: Created 1000 FASTA files.
# Processed batch 56: Created 1000 FASTA files.
# Processed batch 57: Created 1000 FASTA files.
# Processed batch 58: Created 1000 FASTA files.
# Processed batch 59: Created 1000 FASTA files.
# Processed batch 60: Created 1000 FASTA files.
# Processed batch 61: Created 1000 FASTA files.
# Processed batch 62: Created 1000 FASTA files.
# Processed batch 63: Created 1000 FASTA files.
# Processed batch 64: Created 1000 FASTA files.
# Processed batch 65: Created 730 FASTA files.

# %%
# 1. Ensure output directories exist before running anything
os.makedirs("./data/aligned_families", exist_ok=True)
os.makedirs("./data/trees", exist_ok=True)

for family in families:
    family_id = family[0]

    # Run MUSCLE to align the sequences
    input_file = f"{OUTPUT_DIR}/{family_id}.fasta"
    output_file = f"./data/aligned_families/{family_id}_aligned.fasta"
    cmd = ["muscle", "-align", input_file, "-output", output_file]
    result = subprocess.run(cmd, capture_output=True, text=True)

    if result.returncode == 0:
        print("Alignment successful!")
    else:
        print(f"Error: {result.stderr}")
    
    # Run IQ-TREE to build the phylogenetic tree
    aligned_file = f"./data/aligned_families/{family_id}_aligned.fasta"
    tree_output = f"./data/trees/{family_id}"
    iqtree_cmd = ["iqtree", "-s", output_file, "-nt", "AUTO", "-pre", tree_output]
    iqtree_result = subprocess.run(iqtree_cmd)
# Out:
# Alignment successful!
# Alignment successful!
# Alignment successful!
# Alignment successful!
# Alignment successful!
# Alignment successful!
# Alignment successful!
# Alignment successful!
# Alignment successful!
# Alignment successful!
# Alignment successful!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       4     # Run MUSCLE to align the sequences
#       5     input_file = f"{OUTPUT_DIR}/{family_id}.fasta"
#       6     output_file = f"./data/aligned_families/{family_id}_aligned.fasta"
#       7     cmd = ["muscle", "-align", input_file, "-output", output_file]
# ----> 8     result = subprocess.run(cmd, capture_output=True, text=True)
#       9
#      10     if result.returncode == 0:
#      11         print("Alignment successful!")
#
# File ~/miniconda3/envs/phylo_trees/lib/python3.14t/subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File ~/miniconda3/envs/phylo_trees/lib/python3.14t/subprocess.py:1220, in Popen.communicate(self, input, timeout)
#    1217     endtime = None
#    1219 try:
# -> 1220     stdout, stderr = self._communicate(input, endtime, timeout)
#    1221 except KeyboardInterrupt:
#    1222     # https://bugs.python.org/issue25942
#    1223     # See the detailed comment in .wait().
#    1224     if timeout is not None:
#
# File ~/miniconda3/envs/phylo_trees/lib/python3.14t/subprocess.py:2152, in Popen._communicate(self, input, endtime, orig_timeout)
#    2145     self._check_timeout(endtime, orig_timeout,
#    2146                         stdout, stderr,
#    2147                         skip_check_and_raise=True)
#    2148     raise RuntimeError(  # Impossible :)
#    2149         '_check_timeout(..., skip_check_and_raise=True) '
#    2150         'failed to raise TimeoutExpired.')
# -> 2152 ready = selector.select(timeout)
#    2153 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2155 # XXX Rewrite these to use non-blocking I/O on the file
#    2156 # objects; they are no longer using C stdio!
#
# File ~/miniconda3/envs/phylo_trees/lib/python3.14t/selectors.py:398, in _PollLikeSelector.select(self, timeout)
#     396 ready = []
#     397 try:
# --> 398     fd_event_list = self._selector.poll(timeout)
#     399 except InterruptedError:
#     400     return ready
#
# KeyboardInterrupt:

# %%
input_file = "input.fasta"
output_file = "aligned.fasta"

# Construct the command as a list
cmd = ["muscle", "-align", input_file, "-output", output_file]

# Execute the command
result = subprocess.run(cmd, capture_output=True, text=True)

if result.returncode == 0:
    print("Alignment successful!")
else:
    print(f"Error: {result.stderr}")
# Out:
# Error:
# muscle 5.3.linux64 []  11.9Gb RAM, 12 cores
# Built Jul 30 2025 21:13:04
# (C) Copyright 2004-2021 Robert C. Edgar.
# https://drive5.com
#
# [align input.fasta]
#
# ---Fatal error---
# Cannot open input.fasta, errno=2 No such file or directory
